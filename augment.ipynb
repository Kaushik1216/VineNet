# %%
# %pip install -U albumentations

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kaushik vishwakarma\onedrive\desktop\projects\dlimageseg-aug\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import albumentations as A        # For data augmentation
import cv2                        # For loading images
import matplotlib.pyplot as plt   # For plotting images
import numpy as np
import os
import hashlib

# %%
# making a function to load the image
def load_img(path):
    image = cv2.imread(path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
orig_img_path ='dataset/images'
orig_mask_path = "dataset/masks"

out_img_path = "output/images"
out_mask_path = "output/masks"

# %%
transform = A.Compose([
    A.Rotate(limit=30, p=0.5),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.OneOf([
        A.RandomGamma(),
        A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2),
    ], p=0.3),
    A.GaussNoise(var_limit=(10.0, 50.0), p=0.2),
    A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.2),
])

# %%
def give_image_name(img_path , x , y):
    
    file_name = img_path.split("/")[-1]
    base, ext = os.path.splitext(file_name)

    # Generate a hash using the base name
    hash_object = hashlib.sha256(base.encode("utf-8"))
    hex_digest = hash_object.hexdigest()[:10]  # Truncate to shorten the hash

    # Combine the base name, hash, and extension for the unique name
    unique_filename = f"{base}_{hex_digest}_{x}{y}{ext}"

    return unique_filename

# %%
def augmented_image(img_path , mask_path , output_img_dir , output_mask_dir , addition_hash ,noOfAug = 1 ):
    
    image = load_img(img_path)
    mask = load_img(mask_path)

    for i in range (noOfAug):

        transformed = transform(image = image , mask = mask)

        aug_image = transformed['image']
        aug_mask = transformed['mask']

        output_img_name = give_image_name(img_path , i , addition_hash)

        cv2.imwrite(os.path.join(output_img_dir, output_img_name), aug_image)
        cv2.imwrite(os.path.join(output_mask_dir, output_img_name), aug_mask)

# %%
# img_path = "dataset/images/Block_1C1_Row_1_Middle_1003.png"
# mask_path = "dataset/masks/Block_1C1_Row_1_Middle_1003.png"

# augmented_image(img_path , mask_path , out_img_path , out_mask_path  , 1 ,noOfAug=10)

# %%
def list_dir(path):
  images  = []

  for filename in os.listdir(path):
    # Check if file extension is an image format
    if filename.endswith(('.jpg', '.jpeg', '.png')):
      # Construct the full image path
      image_path = os.path.join(path, filename).replace("\\", "/")
      # Append the path to the list
      images.append(image_path)
  images.sort()
  return images

# %%
orig_images = list_dir(orig_img_path)
mask_images = list_dir(orig_mask_path)

print(orig_images)
print(mask_images)
# Out:
# ['dataset/images/Block_1C1_Row_1_Middle_1003.png', 'dataset/images/Block_1C1_Row_1_Middle_1013.png', 'dataset/images/Block_1C1_Row_1_Middle_1018.png', 'dataset/images/Block_1C1_Row_1_Middle_1023.png', 'dataset/images/Block_1C1_Row_1_Middle_1048.png', 'dataset/images/Block_1C1_Row_1_Middle_1058.png', 'dataset/images/Block_1C1_Row_1_Middle_1063.png', 'dataset/images/Block_1C1_Row_1_Middle_1068.png', 'dataset/images/Block_1C1_Row_1_Middle_1073.png', 'dataset/images/Block_1C1_Row_1_Middle_1078.png', 'dataset/images/Block_1C1_Row_1_Middle_1083.png', 'dataset/images/Block_1C1_Row_1_Middle_1103.png', 'dataset/images/Block_1C1_Row_1_Middle_1108.png', 'dataset/images/Block_1C1_Row_1_Middle_1113.png', 'dataset/images/Block_1C1_Row_1_Middle_1133.png', 'dataset/images/Block_1C1_Row_1_Middle_1138.png', 'dataset/images/Block_1C1_Row_1_Middle_1143.png', 'dataset/images/Block_1C1_Row_1_Middle_1148.png', 'dataset/images/Block_1C1_Row_1_Middle_1153.png', 'dataset/images/Block_1C1_Row_1_Middle_1158.png', 'dataset/images/Block_1C1_Row_1_Middle_1163.png', 'dataset/images/Block_1C1_Row_1_Middle_1173.png', 'dataset/images/Block_1C1_Row_1_Middle_1178.png', 'dataset/images/Block_1C1_Row_1_Middle_1183.png', 'dataset/images/Block_1C1_Row_1_Middle_1213.png', 'dataset/images/Block_1C1_Row_1_Middle_1218.png', 'dataset/images/Block_1C1_Row_1_Middle_1238.png', 'dataset/images/Block_1C1_Row_1_Middle_1243.png', 'dataset/images/Block_1C1_Row_1_Middle_1248.png', 'dataset/images/Block_1C1_Row_1_Middle_1253.png', 'dataset/images/Block_1C1_Row_1_Middle_1263.png', 'dataset/images/Block_1C1_Row_1_Middle_1273.png', 'dataset/images/Block_1C1_Row_1_Middle_1278.png', 'dataset/images/Block_1C1_Row_1_Middle_1283.png', 'dataset/images/Block_1C1_Row_1_Middle_1303.png', 'dataset/images/Block_1C1_Row_1_Middle_1308.png', 'dataset/images/Block_1C1_Row_1_Middle_1333.png', 'dataset/images/Block_1C1_Row_1_Middle_1338.png', 'dataset/images/Block_1C1_Row_1_Middle_1353.png', 'dataset/images/Block_1C1_Row_1_Middle_1358.png', 'dataset/images/Block_1C1_Row_1_Middle_1368.png', 'dataset/images/Block_1C1_Row_1_Middle_1373.png', 'dataset/images/Block_1C1_Row_1_Middle_1378.png', 'dataset/images/Block_1C1_Row_1_Middle_1383.png', 'dataset/images/Block_1C1_Row_1_Middle_1403.png', 'dataset/images/Block_1C1_Row_1_Middle_1408.png', 'dataset/images/Block_1C1_Row_1_Middle_1413.png', 'dataset/images/Block_1C1_Row_1_Middle_1443.png', 'dataset/images/Block_1C1_Row_1_Middle_1448.png', 'dataset/images/Block_1C1_Row_1_Middle_1453.png', 'dataset/images/Block_1C1_Row_1_Middle_1458.png', 'dataset/images/Block_1C1_Row_1_Middle_1473.png', 'dataset/images/Block_1C1_Row_1_Middle_1482.png', 'dataset/images/Block_1C1_Row_1_Middle_1514.png', 'dataset/images/Block_1C1_Row_1_Middle_1526.png', 'dataset/images/Block_1C1_Row_1_Middle_1542.png', 'dataset/images/Block_1C1_Row_1_Middle_1546.png', 'dataset/images/Block_1C1_Row_1_Middle_1554.png', 'dataset/images/Block_1C1_Row_1_Middle_1570.png', 'dataset/images/Block_1C1_Row_1_Middle_1578.png', 'dataset/images/Block_1C1_Row_1_Middle_1586.png', 'dataset/images/Block_1C1_Row_1_Middle_1602.png', 'dataset/images/Block_1C1_Row_1_Middle_1606.png', 'dataset/images/Block_1C1_Row_1_Middle_1610.png', 'dataset/images/Block_1C1_Row_1_Middle_1614.png', 'dataset/images/Block_1C1_Row_1_Middle_1618.png', 'dataset/images/Block_1C1_Row_1_Middle_1630.png', 'dataset/images/Block_1C1_Row_1_Middle_1638.png', 'dataset/images/Block_1C1_Row_1_Middle_1642.png', 'dataset/images/Block_1C1_Row_1_Middle_1650.png', 'dataset/images/Block_1C1_Row_1_Middle_1658.png', 'dataset/images/Block_1C1_Row_1_Middle_1666.png', 'dataset/images/Block_1C1_Row_1_Middle_1682.png', 'dataset/images/Block_1C1_Row_1_Middle_1686.png', 'dataset/images/Block_1C1_Row_1_Middle_1690.png', 'dataset/images/Block_1C1_Row_1_Middle_1694.png', 'dataset/images/Block_1C1_Row_1_Middle_1698.png', 'dataset/images/Block_1C1_Row_1_Middle_1706.png', 'dataset/images/Block_1C1_Row_1_Middle_1710.png', 'dataset/images/Block_1C1_Row_1_Middle_1714.png', ...
# ['dataset/masks/Block_1C1_Row_1_Middle_1003.png', 'dataset/masks/Block_1C1_Row_1_Middle_1013.png', 'dataset/masks/Block_1C1_Row_1_Middle_1018.png', 'dataset/masks/Block_1C1_Row_1_Middle_1023.png', 'dataset/masks/Block_1C1_Row_1_Middle_1048.png', 'dataset/masks/Block_1C1_Row_1_Middle_1058.png', 'dataset/masks/Block_1C1_Row_1_Middle_1063.png', 'dataset/masks/Block_1C1_Row_1_Middle_1068.png', 'dataset/masks/Block_1C1_Row_1_Middle_1073.png', 'dataset/masks/Block_1C1_Row_1_Middle_1078.png', 'dataset/masks/Block_1C1_Row_1_Middle_1083.png', 'dataset/masks/Block_1C1_Row_1_Middle_1103.png', 'dataset/masks/Block_1C1_Row_1_Middle_1108.png', 'dataset/masks/Block_1C1_Row_1_Middle_1113.png', 'dataset/masks/Block_1C1_Row_1_Middle_1133.png', 'dataset/masks/Block_1C1_Row_1_Middle_1138.png', 'dataset/masks/Block_1C1_Row_1_Middle_1143.png', 'dataset/masks/Block_1C1_Row_1_Middle_1148.png', 'dataset/masks/Block_1C1_Row_1_Middle_1153.png', 'dataset/masks/Block_1C1_Row_1_Middle_1158.png', 'dataset/masks/Block_1C1_Row_1_Middle_1163.png', 'dataset/masks/Block_1C1_Row_1_Middle_1173.png', 'dataset/masks/Block_1C1_Row_1_Middle_1178.png', 'dataset/masks/Block_1C1_Row_1_Middle_1183.png', 'dataset/masks/Block_1C1_Row_1_Middle_1213.png', 'dataset/masks/Block_1C1_Row_1_Middle_1218.png', 'dataset/masks/Block_1C1_Row_1_Middle_1238.png', 'dataset/masks/Block_1C1_Row_1_Middle_1243.png', 'dataset/masks/Block_1C1_Row_1_Middle_1248.png', 'dataset/masks/Block_1C1_Row_1_Middle_1253.png', 'dataset/masks/Block_1C1_Row_1_Middle_1263.png', 'dataset/masks/Block_1C1_Row_1_Middle_1273.png', 'dataset/masks/Block_1C1_Row_1_Middle_1278.png', 'dataset/masks/Block_1C1_Row_1_Middle_1283.png', 'dataset/masks/Block_1C1_Row_1_Middle_1303.png', 'dataset/masks/Block_1C1_Row_1_Middle_1308.png', 'dataset/masks/Block_1C1_Row_1_Middle_1333.png', 'dataset/masks/Block_1C1_Row_1_Middle_1338.png', 'dataset/masks/Block_1C1_Row_1_Middle_1353.png', 'dataset/masks/Block_1C1_Row_1_Middle_1358.png', 'dataset/masks/Block_1C1_Row_1_Middle_1368.png', 'dataset/masks/Block_1C1_Row_1_Middle_1373.png', 'dataset/masks/Block_1C1_Row_1_Middle_1378.png', 'dataset/masks/Block_1C1_Row_1_Middle_1383.png', 'dataset/masks/Block_1C1_Row_1_Middle_1403.png', 'dataset/masks/Block_1C1_Row_1_Middle_1408.png', 'dataset/masks/Block_1C1_Row_1_Middle_1413.png', 'dataset/masks/Block_1C1_Row_1_Middle_1443.png', 'dataset/masks/Block_1C1_Row_1_Middle_1448.png', 'dataset/masks/Block_1C1_Row_1_Middle_1453.png', 'dataset/masks/Block_1C1_Row_1_Middle_1458.png', 'dataset/masks/Block_1C1_Row_1_Middle_1473.png', 'dataset/masks/Block_1C1_Row_1_Middle_1482.png', 'dataset/masks/Block_1C1_Row_1_Middle_1514.png', 'dataset/masks/Block_1C1_Row_1_Middle_1526.png', 'dataset/masks/Block_1C1_Row_1_Middle_1542.png', 'dataset/masks/Block_1C1_Row_1_Middle_1546.png', 'dataset/masks/Block_1C1_Row_1_Middle_1554.png', 'dataset/masks/Block_1C1_Row_1_Middle_1570.png', 'dataset/masks/Block_1C1_Row_1_Middle_1578.png', 'dataset/masks/Block_1C1_Row_1_Middle_1586.png', 'dataset/masks/Block_1C1_Row_1_Middle_1602.png', 'dataset/masks/Block_1C1_Row_1_Middle_1606.png', 'dataset/masks/Block_1C1_Row_1_Middle_1610.png', 'dataset/masks/Block_1C1_Row_1_Middle_1614.png', 'dataset/masks/Block_1C1_Row_1_Middle_1618.png', 'dataset/masks/Block_1C1_Row_1_Middle_1630.png', 'dataset/masks/Block_1C1_Row_1_Middle_1638.png', 'dataset/masks/Block_1C1_Row_1_Middle_1642.png', 'dataset/masks/Block_1C1_Row_1_Middle_1650.png', 'dataset/masks/Block_1C1_Row_1_Middle_1658.png', 'dataset/masks/Block_1C1_Row_1_Middle_1666.png', 'dataset/masks/Block_1C1_Row_1_Middle_1682.png', 'dataset/masks/Block_1C1_Row_1_Middle_1686.png', 'dataset/masks/Block_1C1_Row_1_Middle_1690.png', 'dataset/masks/Block_1C1_Row_1_Middle_1694.png', 'dataset/masks/Block_1C1_Row_1_Middle_1698.png', 'dataset/masks/Block_1C1_Row_1_Middle_1706.png', 'dataset/masks/Block_1C1_Row_1_Middle_1710.png', 'dataset/masks/Block_1C1_Row_1_Middle_1714.png', 'dataset/masks/Block_1C1_Row_1_Middle_1718.png', 'dataset/masks/Block_1C1_Row_1 ...

# %%
for i in range(len(orig_images)):
    augmented_image(orig_images[i] , mask_images[i] , out_img_path , out_mask_path  , 1 ,noOfAug=5)

# %%
# Out:
# ['dataset/masks\\Block_1C1_Row_1_Middle_1003.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1013.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1018.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1023.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1048.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1058.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1063.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1068.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1073.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1078.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1083.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1103.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1108.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1113.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1133.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1138.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1143.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1148.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1153.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1158.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1163.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1173.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1178.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1183.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1213.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1218.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1238.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1243.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1248.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1253.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1263.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1273.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1278.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1283.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1303.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1308.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1333.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1338.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1353.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1358.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1368.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1373.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1378.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1383.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1403.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1408.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1413.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1443.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1448.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1453.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1458.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1473.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1482.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1514.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1526.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1542.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1546.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1554.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1570.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1578.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1586.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1602.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1606.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1610.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1614.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1618.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1630.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1638.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1642.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1650.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1658.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1666.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1682.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1686.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1690.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1694.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1698.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1706.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1710.png', 'dataset/masks\\Block_1C1_Row_1_Middle_1714.png', ...
